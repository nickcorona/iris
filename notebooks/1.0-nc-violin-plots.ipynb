# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_pickle('../data/raw/iris.pickle')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
sns.catplot('class', 'sepal_length', kind='violin', data=df)

# %%
sns.catplot('class', 'sepal_width', kind='violin', data=df)

# %%
sns.catplot('class', 'petal_length', kind='violin', data=df)

# %%
sns.catplot('class', 'petal_width', kind='violin', data=df)

# %%
sns.pairplot(df, hue='class')

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64
